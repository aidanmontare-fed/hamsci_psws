# %% [markdown]
# # Grape V1 Single Station Time Series
# The purpose of this notebook is to provide a one-stop shop for plotting data from the prototype of the Grape 1 Low-Cost Personal Space Weather Station.
#
# This notebook was created by Kristina Collins KD8OXT. Code was contributed by Aidan Montare KB3UMD, Bob Benedict KD8CGH, and Nathaniel Frissell W2NAF. Hardware designed by John Gibbons. Node maintainers are listed in the `nodelist.csv` file which accompanies this notebook.
#
# ## Instructions:
# Data is permanently stored at [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.6622112.svg)](https://doi.org/10.5281/zenodo.6622112). To use this notebook, download the data from the repository and unzip it into the `data/` directory.

# %%
import datetime
import pytz

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

from hamsci_psws import geopack,grape1

# %%
mpl.rcParams['font.size']        = 16
mpl.rcParams['font.weight']      = 'bold'
mpl.rcParams['axes.labelweight'] = 'bold'
mpl.rcParams['axes.titleweight'] = 'bold'
mpl.rcParams['axes.grid']        = True
mpl.rcParams['grid.linestyle']   = ':'
mpl.rcParams['figure.figsize']   = np.array([15, 8])
mpl.rcParams['axes.xmargin']     = 0

# %%
freq            = 10e6 # MHz
sTime           = datetime.datetime(2021,10,28, tzinfo=pytz.UTC)
eTime           = sTime + datetime.timedelta(days=1)

inventory       = grape1.DataInventory()
inventory.filter(freq=freq,sTime=sTime,eTime=eTime)
grape_nodes     = grape1.GrapeNodes(logged_nodes=inventory.logged_nodes)

# %%
node_nrs        = inventory.get_nodes()
gds = []
for node in node_nrs:
    print('================================================================================')
    print('Loading Node {!s}'.format(node))
    gd = grape1.Grape1Data(node,freq,sTime,eTime,inventory=inventory,grape_nodes=grape_nodes)
    gd.process_data()
    gds.append(gd)
    print()

mp          = grape1.GrapeMultiplot(gds)
# Out:
# ================================================================================
# Loading Node 7
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.806757
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.021754
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:01.010065
# dB Conversion
#   dB Conversion Time: 0:00:00.002472
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006285
#
# Total Processing Time: 0:00:01.847664
#
# ================================================================================
# Loading Node 8
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.799626
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.021188
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:01.009007
# dB Conversion
#   dB Conversion Time: 0:00:00.001473
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006140
#
# Total Processing Time: 0:00:01.837742
#
# ================================================================================
# Loading Node 9
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.792065
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.026447
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.809172
# dB Conversion
#   dB Conversion Time: 0:00:00.001651
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006137
#
# Total Processing Time: 0:00:01.635951
#
# ================================================================================
# Loading Node 10
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.795922
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.025657
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.812717
# dB Conversion
#   dB Conversion Time: 0:00:00.001921
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006346
#
# Total Processing Time: 0:00:01.643215
#
# ================================================================================
# Loading Node 13
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.997732
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.023532
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.809336
# dB Conversion
#   dB Conversion Time: 0:00:00.002439
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006145
#
# Total Processing Time: 0:00:01.839505
#
# ================================================================================
# Loading Node 14
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.795527
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.021235
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:01.001881
# dB Conversion
#   dB Conversion Time: 0:00:00.001649
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006219
#
# Total Processing Time: 0:00:01.826820
#
# ================================================================================
# Loading Node 15
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.753004
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.022556
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:01.016755
# dB Conversion
#   dB Conversion Time: 0:00:00.001603
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006246
#
# Total Processing Time: 0:00:01.800454
#
# ================================================================================
# Loading Node 29
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.790006
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.020785
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.805473
# dB Conversion
#   dB Conversion Time: 0:00:00.001533
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006187
#
# Total Processing Time: 0:00:01.624292
#
# ================================================================================
# Loading Node 34
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.794235
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.020778
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.809358
# dB Conversion
#   dB Conversion Time: 0:00:00.001982
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006114
#
# Total Processing Time: 0:00:01.632878
#
# ================================================================================
# Loading Node 36
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.989679
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.022445
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.811082
# dB Conversion
#   dB Conversion Time: 0:00:00.001686
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.006323
#
# Total Processing Time: 0:00:01.831511

# %%
# WWV Coordinates
solar_lat   =   40.6683
solar_lon   = -105.0384

color_dct   = {'ckey':'lon'}
xkey        = 'UTC'
mp.multiplot('filtered',color_dct=color_dct,xkey=xkey,solar_lat=solar_lat,solar_lon=solar_lon)
# Out:
# {'fig': <Figure size 1584x1152 with 4 Axes>}

# %%
xkey        = 'LMT'
mp.multiplot('filtered',color_dct=color_dct,xkey=xkey,solar_lat=solar_lat,solar_lon=solar_lon)
# Out:
# {'fig': <Figure size 1584x1152 with 4 Axes>}
