# %% [markdown]
# # Grape V1 Multiple Station Time Series Show Solar Flare Impacts
# The purpose of this notebook is to provide a one-stop shop for plotting data from the prototype of the Grape 1 Low-Cost Personal Space Weather Station.
#
# This notebook was created by Nathaniel Frissell W2NAF and Kristina Collins KD8OXT. Code was contributed by Aidan Montare KB3UMD, Bob Benedict KD8CGH. Hardware designed by John Gibbons. Node maintainers are listed in the `nodelist.csv` file which accompanies this notebook.
#
# ## Instructions:
# Data is permanently stored at [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.6622112.svg)](https://doi.org/10.5281/zenodo.6622112). To use this notebook, download the data from the repository and unzip it into the `data/` directory.

# %%
import datetime
import pytz

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

from hamsci_psws import grape1

# %%
mpl.rcParams['font.size']        = 18
mpl.rcParams['font.weight']      = 'bold'
mpl.rcParams['axes.labelweight'] = 'bold'
mpl.rcParams['axes.titleweight'] = 'bold'
mpl.rcParams['axes.grid']        = True
mpl.rcParams['grid.linestyle']   = ':'
mpl.rcParams['figure.figsize']   = np.array([15, 8])
mpl.rcParams['axes.xmargin']     = 0

# %%
freq            = 10e6 # MHz
sTime           = datetime.datetime(2021,10,28,12, tzinfo=pytz.UTC)
eTime           = datetime.datetime(2021,10,28,18, tzinfo=pytz.UTC)

inventory       = grape1.DataInventory()
inventory.filter(freq=freq,sTime=sTime,eTime=eTime)
grape_nodes     = grape1.GrapeNodes(logged_nodes=inventory.logged_nodes)

# %%
node_nrs        = inventory.get_nodes()
gds = []
for node in node_nrs:
    
    # Skip nodes 9 and 10 because they were not working correctly during the 28 Oct 2021 Solar Flare event.
    if node in [9,10]:
        continue
    
    print('================================================================================')
    print('Loading Node {!s}'.format(node))
    gd = grape1.Grape1Data(node,freq,sTime,eTime,inventory=inventory,grape_nodes=grape_nodes)
    gd.process_data()
    gds.append(gd)
    print()

mp          = grape1.GrapeMultiplot(gds)
# Out:
# ================================================================================
# Loading Node 7
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.211768
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.011031
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.284612
# dB Conversion
#   dB Conversion Time: 0:00:00.000730
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003628
#
# Total Processing Time: 0:00:00.512043
#
# ================================================================================
# Loading Node 8
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.207252
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.008845
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.214405
# dB Conversion
#   dB Conversion Time: 0:00:00.000796
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003562
#
# Total Processing Time: 0:00:00.435285
#
# ================================================================================
# Loading Node 13
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.280468
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.008986
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.212558
# dB Conversion
#   dB Conversion Time: 0:00:00.000804
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003350
#
# Total Processing Time: 0:00:00.506437
#
# ================================================================================
# Loading Node 14
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.210350
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.008875
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.287569
# dB Conversion
#   dB Conversion Time: 0:00:00.000839
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003219
#
# Total Processing Time: 0:00:00.511274
#
# ================================================================================
# Loading Node 15
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.169064
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.008558
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.216391
# dB Conversion
#   dB Conversion Time: 0:00:00.000783
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003753
#
# Total Processing Time: 0:00:00.398822
#
# ================================================================================
# Loading Node 34
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.280851
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.008645
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.213657
# dB Conversion
#   dB Conversion Time: 0:00:00.000761
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003488
#
# Total Processing Time: 0:00:00.507672
#
# ================================================================================
# Loading Node 36
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.208945
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.008714
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.282165
# dB Conversion
#   dB Conversion Time: 0:00:00.000851
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003371
#
# Total Processing Time: 0:00:00.504315
#
# ================================================================================
# Loading Node 29
# Loading Raw Data:   0%|                                                                                       …
# Processing data using "standard" profile...
#
# Computing Solar Local Time on raw data...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.208943
# Resampling data with 1.0 second cadence...
#   Resampling Time: 0:00:00.008741
# Computing Solar Local Time on resampled...
#   0%|                                                                                                         …
#   Solar Time Computation Time: 0:00:00.282201
# dB Conversion
#   dB Conversion Time: 0:00:00.000924
# Filtering data with 3.3333 minute low-pass Butterworth filter...
#   Filtering Time: 0:00:00.003041
#
# Total Processing Time: 0:00:00.504122

# %%
# WWV Coordinates
solar_lat   =   40.6683
solar_lon   = -105.0384

color_dct   = {'ckey':'lon'}
xkey        = 'UTC'
events      = [{'datetime':datetime.datetime(2021,10,28,15,35),'label':'X1 Solar Flare'}]
mp.multiplot('filtered',color_dct=color_dct,xkey=xkey,solar_lat=solar_lat,solar_lon=solar_lon,events=events,plot_GOES=True)
plt.show()
# Out:
# INFO:root:Using locally cached files for 2021 Oct 28 - 2021 Oct 28.
